# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_csv('weatherAUS.csv')

# %%
df0.head(5)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0           W           44.0          W      ...             22.0
# 1         WNW           44.0        NNW      ...             25.0
# 2         WSW           46.0          W      ...             30.0
# 3          NE           24.0         SE      ...             16.0
# 4           W           41.0        ENE      ...             33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
m=(df0[['Temp9am','Temp3pm','WindSpeed9am','WindSpeed3pm','Location']])

# %%
df=(m.dropna(how="any",axis=0))

# %%
df
# Out:
#         Temp9am  Temp3pm  WindSpeed9am  WindSpeed3pm Location
# 0          16.9     21.8          20.0          24.0   Albury
# 1          17.2     24.3           4.0          22.0   Albury
# 2          21.0     23.2          19.0          26.0   Albury
# 3          18.1     26.5          11.0           9.0   Albury
# 4          17.8     29.7           7.0          20.0   Albury
# 5          20.6     28.9          19.0          24.0   Albury
# 6          18.1     24.6          20.0          24.0   Albury
# 7          16.3     25.5           6.0          17.0   Albury
# 8          18.3     30.2           7.0          28.0   Albury
# 9          20.1     28.2          15.0          11.0   Albury
# 10         20.4     28.8          17.0           6.0   Albury
# 11         15.9     17.0          15.0          13.0   Albury
# 12         17.4     15.8          28.0          28.0   Albury
# 13         15.8     19.8          24.0          20.0   Albury
# ...

# %%
df1=(df[df["Location"]=="Richmond"][:1000])

# %%
df1
# Out:
#        Temp9am  Temp3pm  WindSpeed9am  WindSpeed3pm  Location
# 26546     20.0     32.1           9.0          31.0  Richmond
# 26547     20.0     23.7          13.0          35.0  Richmond
# 26548     16.8     20.0           7.0           9.0  Richmond
# 26549     19.6     29.3           4.0          17.0  Richmond
# 26550     21.2     36.1           7.0          24.0  Richmond
# 26551     22.5     38.0           6.0          11.0  Richmond
# 26552     22.2     35.8           9.0          19.0  Richmond
# 26553     20.2     18.3          11.0          19.0  Richmond
# 26554     16.9     19.9          17.0          13.0  Richmond
# 26555     17.2     23.3           6.0          19.0  Richmond
# 26556     19.4     27.8           2.0          17.0  Richmond
# 26557     17.8     26.4           4.0          30.0  Richmond
# 26558     22.7     29.3          11.0          17.0  Richmond
# 26559     22.3     37.0           4.0          13.0  Richmond
# ...

# %%
df2=(df[df["Location"]=="Sydney"][:1000])

# %%
df2
# Out:
#        Temp9am  Temp3pm  WindSpeed9am  WindSpeed3pm Location
# 29497     20.7     20.9          17.0          20.0   Sydney
# 29498     22.4     24.8           9.0          13.0   Sydney
# 29499     23.5     23.0          17.0           2.0   Sydney
# 29500     21.4     20.9          22.0          20.0   Sydney
# 29501     22.5     25.5          11.0           6.0   Sydney
# 29502     23.8     26.0           9.0          22.0   Sydney
# 29503     21.7     22.3          15.0          15.0   Sydney
# 29504     18.9     21.1           7.0          15.0   Sydney
# 29505     17.1     16.5          19.0           9.0   Sydney
# 29506     17.2     23.3          11.0          20.0   Sydney
# 29507     18.9     23.7           9.0          26.0   Sydney
# 29508     22.9     24.7           7.0          24.0   Sydney
# 29509     20.9     21.0          24.0          30.0   Sydney
# 29510     18.4     23.3          15.0          19.0   Sydney
# ...

# %%
df3=(df[df["Location"]=="Portland"][:1000])

# %%
df3
# Out:
#        Temp9am  Temp3pm  WindSpeed9am  WindSpeed3pm  Location
# 72756     13.7     14.5          28.0          28.0  Portland
# 72757     11.9     14.0          20.0          17.0  Portland
# 72758     11.6     17.5           9.0          15.0  Portland
# 72759     14.7     18.1          11.0          17.0  Portland
# 72760     14.9     18.0          20.0          31.0  Portland
# 72761     15.4     18.9          17.0          26.0  Portland
# 72762     14.6     17.9           9.0          28.0  Portland
# 72763     12.9     15.0          20.0          22.0  Portland
# 72764     14.1     17.2          17.0          19.0  Portland
# 72765     15.4     17.7          15.0          19.0  Portland
# 72766     14.0     17.5           0.0          24.0  Portland
# 72767     16.2     20.8           9.0          13.0  Portland
# 72768     21.4     36.3          15.0          30.0  Portland
# 72769     15.4     17.2          17.0          15.0  Portland
# ...

# %%
df_new=pd.concat((df1,df2,df3))

# %%
df_new
# Out:
#        Temp9am  Temp3pm  WindSpeed9am  WindSpeed3pm  Location
# 26546     20.0     32.1           9.0          31.0  Richmond
# 26547     20.0     23.7          13.0          35.0  Richmond
# 26548     16.8     20.0           7.0           9.0  Richmond
# 26549     19.6     29.3           4.0          17.0  Richmond
# 26550     21.2     36.1           7.0          24.0  Richmond
# 26551     22.5     38.0           6.0          11.0  Richmond
# 26552     22.2     35.8           9.0          19.0  Richmond
# 26553     20.2     18.3          11.0          19.0  Richmond
# 26554     16.9     19.9          17.0          13.0  Richmond
# 26555     17.2     23.3           6.0          19.0  Richmond
# 26556     19.4     27.8           2.0          17.0  Richmond
# 26557     17.8     26.4           4.0          30.0  Richmond
# 26558     22.7     29.3          11.0          17.0  Richmond
# 26559     22.3     37.0           4.0          13.0  Richmond
# ...

# %%
df_new=(df_new.rename(columns={"Temp9am": "0", "Temp3pm": "1", "WindSpeed9am": "2", "WindSpeed3pm": "3", "Location":"4"}))

# %%
df_new
# Out:
#           0     1     2     3         4
# 26546  20.0  32.1   9.0  31.0  Richmond
# 26547  20.0  23.7  13.0  35.0  Richmond
# 26548  16.8  20.0   7.0   9.0  Richmond
# 26549  19.6  29.3   4.0  17.0  Richmond
# 26550  21.2  36.1   7.0  24.0  Richmond
# 26551  22.5  38.0   6.0  11.0  Richmond
# 26552  22.2  35.8   9.0  19.0  Richmond
# 26553  20.2  18.3  11.0  19.0  Richmond
# 26554  16.9  19.9  17.0  13.0  Richmond
# 26555  17.2  23.3   6.0  19.0  Richmond
# 26556  19.4  27.8   2.0  17.0  Richmond
# 26557  17.8  26.4   4.0  30.0  Richmond
# 26558  22.7  29.3  11.0  17.0  Richmond
# 26559  22.3  37.0   4.0  13.0  Richmond
# 26560  29.7  39.9  11.0  24.0  Richmond
# 26561  19.8  30.7   6.0  11.0  Richmond
# 26562  15.9  20.0  11.0  17.0  Richmond
# 26563  18.0  27.1   4.0  11.0  Richmond
# 26564  18.9  31.9   6.0  19.0  Richmond
# 26565  22.7  38.5   4.0  19.0  Richmond
# 26566  26.5  38.1   9.0  17.0  Richmond
# 26567  26.0  30.9  13.0  22.0  Richmond
# ...

# %%
class Perceptron():   # vytvorenie triedy perceptron
    def __init__(self, rychlost_ucenia=0.01, pocet_iteracii=15): # konštruktor - inicializuje atribúty triedy (rýchlosť učenia, počet iterácií)
        self.eta = rychlost_ucenia # priradenie do premennej - prístup k atribútom
        self.n_iter = pocet_iteracii # priradenie do premennej - prístup k atribútom
    
    
    def fit(self, X,y): # metóda procesu učenia 
        self.vahy = np.zeros(1+ X.shape[1]) # šírka poľa váh 
        self.errors_=[] # vytvorenie poľa erorov
        
        self.vahy_to_visualize_1=[] # vytvorenie premenných na vitualizáciu
        self.vahy_to_visualize_2=[]
        self.vahy_to_visualize_3=[]
        
        for i in range(self.n_iter): # cyklus na naplnenie
            errors = 0 # naplnenie matice errors nulami
            for matica,vystup in zip(X,y):
                update = self.eta * (vystup-self.predikcia(matica))
                self.vahy[1:] += update*matica
                self.vahy[0]+= update
                
                print(self.vahy[1:]) # výpis váh
                
                errors += int(update !=0.0)
            self.errors_.append(errors)   
            self.vahy_to_visualize_1.append(self.vahy[0]) # naplnenie premenných
            self.vahy_to_visualize_2.append(self.vahy[1])
            self.vahy_to_visualize_3.append(self.vahy[2])
        return self  

    def net_input(self, X): # výpočet čistého vstupu
        return np.dot(X, self.vahy[1:])+ self.vahy[0]

    def predikcia(self, X): # návrat triedy po kroku
        return np.where(self.net_input(X) >= 0.0, 1, -1)

# %%
import matplotlib.pyplot as plt # importovanie knižnice
